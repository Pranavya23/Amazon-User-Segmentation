# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#   customer_id  customer_visit_score  customer_product_search_score  \
# 0      csid_1             13.168425                       9.447662
# 1      csid_2             17.092979                       7.329056
# 2      csid_3             17.505334                       5.143676
# 3      csid_4             31.423381                       4.917740
# 4      csid_5             11.909502                       4.237073
#
#    customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0           -0.070203            -0.139541                  0.436956
# 1            0.153298            -0.102726                  0.380340
# 2            0.106709             0.262834                  0.417648
# 3           -0.020226            -0.100526                  0.778130
# 4            0.187178             0.172891                  0.162067
#
#    customer_product_variation_score  customer_order_score  \
# 0                          4.705761              2.537985
# ...

# %%
print(set(df['customer_active_segment']))
# Out:
# {nan, 'D', 'A', 'B', 'C', 'AA'}

# %%
print(set(df['X1']))
# Out:
# {nan, 'A', 'F', 'AA', 'BA', 'E'}

# %%
df.describe()
# Out:
#        customer_visit_score  customer_product_search_score  \
# count          10738.000000                   10696.000000
# mean              19.060941                       5.274847
# std                7.419609                       1.882559
# min                0.568965                      -0.161940
# 25%               13.518021                       3.971587
# 50%               18.774109                       5.218479
# 75%               24.501719                       6.520364
# max               47.306691                      16.638243
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# count        10738.000000         10701.000000              10738.000000
# mean             0.175912             0.374230                  2.376895
# std              0.372829             1.222031                  5.601911
# min             -0.547989            -0.462494                  0.028575
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10738 entries, 0 to 10737
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   customer_id                       10738 non-null  object
#  1   customer_visit_score              10738 non-null  float64
#  2   customer_product_search_score     10696 non-null  float64
#  3   customer_ctr_score                10738 non-null  float64
#  4   customer_stay_score               10701 non-null  float64
#  5   customer_frequency_score          10738 non-null  float64
#  6   customer_product_variation_score  10692 non-null  float64
#  7   customer_order_score              10672 non-null  float64
#  8   customer_affinity_score           10738 non-null  float64
#  9   customer_active_segment           10715 non-null  object
#  10  X1                                10701 non-null  object
# ...

# %%
df = df.dropna()

# %%
print(set(df['customer_active_segment']))
print(set(df['X1']))
# Out:
# {'D', 'A', 'B', 'C', 'AA'}
# {'A', 'F', 'AA', 'BA', 'E'}

# %%
l = list(df.columns)
for i in range(1,9):
    df[l[i]] = df[l[i]].fillna(df[l[i]].mean)

# %%
df.head()
# Out:
#   customer_id  customer_visit_score  customer_product_search_score  \
# 0      csid_1             13.168425                       9.447662
# 1      csid_2             17.092979                       7.329056
# 2      csid_3             17.505334                       5.143676
# 3      csid_4             31.423381                       4.917740
# 4      csid_5             11.909502                       4.237073
#
#    customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0           -0.070203            -0.139541                  0.436956
# 1            0.153298            -0.102726                  0.380340
# 2            0.106709             0.262834                  0.417648
# 3           -0.020226            -0.100526                  0.778130
# 4            0.187178             0.172891                  0.162067
#
#    customer_product_variation_score  customer_order_score  \
# 0                          4.705761              2.537985
# ...

# %%
df = df.drop(['customer_id'],axis = 1)
df.head()
# Out:
#    customer_visit_score  customer_product_search_score  customer_ctr_score  \
# 0             13.168425                       9.447662           -0.070203
# 1             17.092979                       7.329056            0.153298
# 2             17.505334                       5.143676            0.106709
# 3             31.423381                       4.917740           -0.020226
# 4             11.909502                       4.237073            0.187178
#
#    customer_stay_score  customer_frequency_score  \
# 0            -0.139541                  0.436956
# 1            -0.102726                  0.380340
# 2             0.262834                  0.417648
# 3            -0.100526                  0.778130
# 4             0.172891                  0.162067
#
#    customer_product_variation_score  customer_order_score  \
# 0                          4.705761              2.537985
# 1                          4.205138              4.193444
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['customer_active_segment'] = le.fit_transform(df['customer_active_segment'])
df['X1'] = le.fit_transform(df['X1'])
df.head()
# Out:
#    customer_visit_score  customer_product_search_score  customer_ctr_score  \
# 0             13.168425                       9.447662           -0.070203
# 1             17.092979                       7.329056            0.153298
# 2             17.505334                       5.143676            0.106709
# 3             31.423381                       4.917740           -0.020226
# 4             11.909502                       4.237073            0.187178
#
#    customer_stay_score  customer_frequency_score  \
# 0            -0.139541                  0.436956
# 1            -0.102726                  0.380340
# 2             0.262834                  0.417648
# 3            -0.100526                  0.778130
# 4             0.172891                  0.162067
#
#    customer_product_variation_score  customer_order_score  \
# 0                          4.705761              2.537985
# 1                          4.205138              4.193444
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
numeric_columns = df.select_dtypes(include=['float64','int32']).columns
scaler = MinMaxScaler()
df[numeric_columns] = scaler.fit_transform(df[numeric_columns])
df.head()
# Out:
#    customer_visit_score  customer_product_search_score  customer_ctr_score  \
# 0              0.269578                       0.571994            0.148038
# 1              0.353548                       0.445888            0.217287
# 2              0.362370                       0.315807            0.202852
# 3              0.660161                       0.302359            0.163523
# 4              0.242642                       0.261843            0.227785
#
#    customer_stay_score  customer_frequency_score  \
# 0             0.021297                  0.007799
# 1             0.023724                  0.006717
# 2             0.047831                  0.007430
# 3             0.023870                  0.014314
# 4             0.041900                  0.002549
#
#    customer_product_variation_score  customer_order_score  \
# 0                          0.122126              0.249190
# 1                          0.090820              0.438887
# ...

# %%
from sklearn.model_selection import train_test_split
X = df.drop('customer_category', axis=1)
y = df['customer_category']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Initialize models
model1 = DecisionTreeClassifier()
model2 = KNeighborsClassifier()
model3 = GaussianNB()
model4 = LogisticRegression(max_iter=1000)
model5 = SVC()
# Train and evaluate each model
def call(model_name, model):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    
    print(f"{model_name}:")
    print(f"  Accuracy: {accuracy:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall: {recall:.4f}")
    print(f"  F1 Score: {f1:.4f}\n")
    
    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Plot heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=model.classes_, yticklabels=model.classes_)
    plt.title(f"{model_name} Confusion Matrix")
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

call('Decision Tree',model1)
# Out:
# Decision Tree:
#   Accuracy: 0.9574
#   Precision: 0.9573
#   Recall: 0.9574
#   F1 Score: 0.9574

# %%
call('KNN',model2)
# Out:
# KNN:
#   Accuracy: 0.9663
#   Precision: 0.9660
#   Recall: 0.9663
#   F1 Score: 0.9647

# %%
call('Naive Bayes',model3)
# Out:
# Naive Bayes:
#   Accuracy: 0.9396
#   Precision: 0.9434
#   Recall: 0.9396
#   F1 Score: 0.9411

# %%
call('Logistic Regression',model4)
# Out:
# Logistic Regression:
#   Accuracy: 0.9644
#   Precision: 0.9645
#   Recall: 0.9644
#   F1 Score: 0.9623

# %%
call('SVM',model5)
# Out:
# SVM:
#   Accuracy: 0.9698
#   Precision: 0.9696
#   Recall: 0.9698
#   F1 Score: 0.9685
